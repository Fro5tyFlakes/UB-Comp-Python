# %% [markdown]
# # Practice making plots
# import package
#
# create data to plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x_data = [4,5,6,13,43,543,3,24,54]
y_data = [12,23,4,43,2,5,6,3,98]

len(y_data)==len(x_data)
# Out:
# True

# %% [markdown]
# Line Plot

# %%
plt.plot([4,5,6,13,43,543,3,24,54],[12,23,4,43,2,5,6,3,98],'r-',marker='^', label = 'apples')
plt.title ('Line plot')
plt.xlabel('x values')
plt.ylabel('y valies')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(x_data,y_data, c ='c', marker='*',label= 'trees')
plt.plot(x_data,Y_new, 'k-',label = 'people')
plt.title('Spooky graph')
plt.xlabel('floor')
plt.ylabel('big trees')
plt.legend()
plt.show()

Y_new=[45,76,2,5,26,76,18,36,9]
len(Y_new)==len(y_data)
# Out:
# True

# %%
plt.hist(x_data,bins= 20, color = 'c',label = 'eating apples')

plt.title('big trees')
plt.xlabel('dirt floor')
plt.ylabel('tall trees')
plt.legend()
plt.show()
